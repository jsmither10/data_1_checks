# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('assets\data.csv')
df.head()
# Out:
#          Queens  Stat 1  Stat 2  Stat 3  Stat 4  Total  Winners Eliminated
# 0      Amethyst      15      20       0     -15     20      NaN        Yes
# 1        Anetra      40       0       0      10     50      1.0         No
# 2   Aura Mayari      20       0       2      -5     17      1.0         No
# 3  Irene Dubois       5       0       6      -5      6      NaN        Yes
# 4           Jax      20       0       6       0     26      NaN         No

# %%
df_sorted = df.sort_values('Total')

sns.barplot(data=df_sorted, x="Total", y="Queens").set(title='Total Points by Queen')
# Out:
# [Text(0.5, 1.0, 'Total Points by Queen')]
