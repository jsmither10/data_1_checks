# %%
import requests
import pandas as pd
import json

# %%
#accessing the API
r = requests.get('https://peoplegeneratorapi.live/api/person/100')
print(r.status_code)
print(r.json())
# Out:
# 200
# [{'name': 'Maryanna Rau', 'age': 26, 'job': 'Radiologic Technologist', 'incomeUSD': 69285, 'creditScore': 621, 'ccNumber': '6304964333975081', 'married': False, 'hasChildren': False, 'height': 171.0, 'weight': 75.2, 'eyeColor': 'BLUE', 'email': 'maryannarau@gmail.com', 'gender': 'Male', 'hasDegree': False, 'bloodType': 'A-', 'username': 'maryanna22', 'politicalLeaning': 0.35, 'religion': 'Hinduism', 'address': {'streetAddress': '1475 Halvorson Trail', 'city': 'Stantsiya Novyy Afon', 'state': 'Shida Kartli', 'country': 'Georgia', 'zip': '5599', 'geonameId': 611717, 'phoneNumber': '+995 285001536', 'ipAddress': '210.162.4.150', 'countryCode': 'GE'}, 'doB': 'Thu Feb 05 05:26:21 UTC 1998', 'gpa': 3.0}, {'name': 'Delphia Fadel', 'age': 17, 'job': 'Student', 'incomeUSD': 0, 'creditScore': 0, 'ccNumber': None, 'married': False, 'hasChildren': False, 'height': 160.0, 'weight': 54.9, 'eyeColor': 'BROWN', 'email': 'delphia@yahoo.com', 'gender': 'Male', 'hasDegree': False, 'bloodType': 'AB-', 'username': 'delphia43', 'politicalLeaning': 0.37, 'religion': 'Christianity', 'address': {'streetAddress': '021 Terrence Freeway', 'city': 'Al Hoceïma', 'state': 'Souss-Massa-Drâa', 'country': 'Morocco', 'zip': '1695', 'geonameId': 2542715, 'phoneNumber': '+212 517799617', 'ipAddress': '123.142.3.160', 'countryCode': 'MA'}, 'doB': 'Mon Oct 29 10:32:10 UTC 2007', 'gpa': 3.3}, {'name': 'Linwood Sanford', 'age': 10, 'job': 'Student', 'incomeUSD': 0, 'creditScore': 0, 'ccNumber': None, 'married': False, 'hasChildren': False, 'height': 175.0, 'weight': 80.2, 'eyeColor': 'GREEN', 'email': 'linwoodsanford@outlook.com', 'gender': 'Male', 'hasDegree': True, 'bloodType': 'A+', 'username': 'linwood98', 'politicalLeaning': -0.67, 'religion': 'Hinduism', 'address': {'streetAddress': '08481 Charlie Islands', 'city': 'Cabinda', 'state': 'Zaire', 'country': 'Angola', 'zip': '2671', 'geonameId': 3347939, 'phoneNumber': '+244 466386339', 'ipAddress': '1.17.13.60', 'countryCode': 'AO'}, 'doB': 'Tue Jun 03 09:10:22 UTC 2014', 'gpa': 0.0}, {'name': 'Jaime Kessler', 'age': 49, 'job': 'C-Suite Executive', 'incomeUSD': 304997, 'creditScore': 600, 'ccNumber': '4404-2290-1012-8550', 'married': True, 'hasChildren': False, 'height': 171.0, 'weight': 70.1, 'eyeColor': 'BROWN', 'email': 'jaimekessler@yahoo.com', 'gender': 'Female', 'hasDegree': False, 'bloodType': 'A+', 'username': 'jaime27', 'politicalLeaning': 0.15, 'religion': 'Christianity', 'address': {'streetAddress': '424 Lasonya Falls', 'city': 'Roseau', 'state': 'Saint George', 'country': 'Dominica', 'zip': '9723', 'geonameId': 3575635, 'phoneNumber': '+1767 4401019939', 'ipAddress': '213.224.76.12', 'countryCode': 'DM'}, 'doB': 'Thu Feb 20 07:46:07 UTC 1975', 'gpa': 2.4}, {'name': 'Brett VonRueden', 'age': 61, 'job': 'Retired', 'incomeUSD': 10071, 'creditScore': 634, 'ccNumber': '3685-265086-9342', 'married': False, 'hasChildren': True, 'height': 161.0, 'weight': 65.9, 'eyeColor': 'GRAY', 'email': 'brettvonrueden@hotmail.com', 'gender': 'Female', 'hasDegree': False, 'bloodType': 'A+', 'username': 'brett47', 'politicalLeaning': 0.0, 'religion': 'Islam', 'address': {'streetAddress': '576 Hoeger Extensions', 'city': 'Antananarivo', 'state': 'Sava', 'country': 'Madagascar', 'zip': '3905', 'geonameId': 1062663, 'phoneNumber': '+261 558159113', 'ipAddress': '35.201.74.25', 'countryCode': 'MG'}, 'doB': 'Tue Mar 12 09:35:16 UTC 1963', 'gpa': 3.5}, {'name': 'Sherwood Jenkins', 'age': 26, 'job': 'History Teacher', 'incomeUSD': 33164, 'creditScore': 543, 'ccNumber': '3717-762260-84560', 'married': False, 'hasChildren': False, 'height': 176.0, 'weight': 65.2, 'eyeColor': 'GRAY', 'email': 'sherwood_jenkins@gmail.com', 'gender': 'Male', 'hasDegree': False, 'bloodType': 'O+', 'username': 'sherwood39', 'politicalLeaning': 0.03, 'religion': 'Christianity', 'address': {'streetAddress': '900 Tonie Oval', 'city': 'Nova Zagora', 'state': 'Sofiya', 'country': 'Bulgaria', 'zip': '7405', 'geonameId': 726418, 'phoneNumber': '+359 728652974',  ...

# %%
#viewing the data as a dataframe
data=r.json()
df = (pd.DataFrame(data))
df.head()
# Out:
#               name  age               job  incomeUSD  creditScore  \
# 0      Joie Bednar   10           Student          0            0
# 1      Elroy Borer   25           Auditor      82132          749
# 2  Santina D'Amore    3           Student          0            0
# 3     Mack Ziemann   26  Nuclear Engineer      80162          581
# 4   Elbert Johnson   10           Student          0            0
#
#               ccNumber  married  hasChildren  height  weight  ...  \
# 0                 None    False        False   165.0    50.1  ...
# 1  6771-8963-9125-6315    False        False   181.0    65.1  ...
# 2                 None    False        False   166.0    70.2  ...
# 3        4704370471115     True         True   155.0    44.1  ...
# 4                 None    False        False   176.0    64.2  ...
#
#                        email  gender hasDegree  bloodType   username  \
# 0    joie.bednar@hotmail.com    Male      True         B+     joie53
# 1     elroyborer@hotmail.com    Male     False         O+    elroy63
# 2          d'amore@yahoo.com  Female      True         B+  santina54
# 3  ziemann.ziemann@yahoo.com  Female     False         B-     mack78
# 4           elbert@gmail.com    Male      True         B-   elbert12
#
#   politicalLeaning      religion  \
# 0             0.05  Christianity
# 1            -0.09  Christianity
# 2            -0.74     Christian
# 3            -0.77  Christianity
# 4             0.13  Christianity
#
#                                              address  \
# 0  {'streetAddress': '4878 Jessenia Cliffs', 'cit...
# 1  {'streetAddress': '1747 Cartwright Alley', 'ci...
# 2  {'streetAddress': '2167 Hudson Flat', 'city': ...
# 3  {'streetAddress': '12598 Rayford Cape', 'city'...
# 4  {'streetAddress': '59528 Funk Island', 'city':...
#
#                             doB  gpa
# 0  Thu Apr 24 17:30:12 UTC 2014  3.1
# 1  Tue Sep 29 01:02:18 UTC 1998  2.9
# 2  Wed Dec 16 09:25:04 UTC 2020  3.0
# 3  Wed Aug 20 23:46:15 UTC 1997  2.3
# 4  Tue Aug 12 01:01:22 UTC 2014  2.0
#
# [5 rows x 21 columns]

# %%
#getting a list of all the column names

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   age               100 non-null    int64
#  2   job               100 non-null    object
#  3   incomeUSD         100 non-null    int64
#  4   creditScore       100 non-null    int64
#  5   ccNumber          76 non-null     object
#  6   married           100 non-null    bool
#  7   hasChildren       100 non-null    bool
#  8   height            100 non-null    float64
#  9   weight            100 non-null    float64
#  10  eyeColor          100 non-null    object
#  11  email             100 non-null    object
#  12  gender            100 non-null    object
#  13  hasDegree         100 non-null    bool
#  14  bloodType         100 non-null    object
#  15  username          100 non-null    object
#  16  politicalLeaning  100 non-null    float64
#  17  religion          100 non-null    object
#  18  address           100 non-null    object
#  19  doB               100 non-null    object
#  20  gpa               100 non-null    float64
# dtypes: bool(3), float64(4), int64(3), object(11)
# memory usage: 14.5+ KB

# %%
#DESCRIPTIVE STAT NUMBER 1 - AGE
min_age = df["age"].min()
print("The youngest person on the list is " + str(min_age))

max_age = df["age"].max()
print("The oldest person on the list is " + str(max_age))

avg_age = df["age"].mean()
print("The average age of the person on the list is " + str(avg_age))
# Out:
# The youngest person on the list is 1
# The oldest person on the list is 70
# The average age of the person on the list is 28.77

# %%
#DESCRIPTIVE STAT NUMBER 2 - Has Children

has_children = df["hasChildren"].value_counts()
print(has_children.to_string())

has_children_true_count = (df["hasChildren"] == True).sum()
print("Out of the 100 people " + str(has_children_true_count) + " have children")
# Out:
# False    69
# True     31
# Out of the 100 peoeple 31 have children

# %%
#Write a query in Pandas to select a particular set of data. This is a mask of users who have children
mask = df["hasChildren"] == True
maskdf = df[mask]
print(maskdf)
# Out:
#                    name  age                                   job  incomeUSD  \
# 3          Mack Ziemann   26                      Nuclear Engineer      80162
# 9      Shelby Romaguera   24                    Physical Therapist      93238
# 15         Retha Rempel   70                               Retired          0
# 17     Ulysses Schulist   54                            Lumberjack      50065
# 18          Allie Berge   41                     Marketing Manager      96117
# 19   Ellsworth Mitchell   21                        E-Sports Coach      75167
# 23       Roderick Wyman   68                        NASA Scientist     108747
# 26      Milissa Mueller   40                      Graphic Designer      76675
# 30           Bree Huels   27                    Facilities Manager      72025
# 31       Reynaldo Jones   44                       Insurance Agent      66299
# 42             Val Ward   51                  Assembly Line Worker      36837
# 46          Zoila Kulas   32       Workforce Management Specialist      74461
# 47      Jeffrey Quitzon   49                             Paralegal      68388
# 51          Cyrus Terry   54                               Auditor      78549
# 54        Simon Reinger   23  Chief Human Resources Officer (CHRO)     184821
# 57       Denis Weissnat   21                           Demographer      71745
# 58       Marla Nitzsche   56                           Audiologist      91579
# 59        Norman Larkin   35                        Office Manager      68546
# 60        Jennie Harvey   21               Costume Designer (Film)      82900
# 63       Jewell Johnson   34                      Marine Biologist      86660
# 68       Shamika Hessel   29               Human Resources Manager      87490
# 72     Valarie Schimmel   47               Market Research Analyst      67431
# 73  Annemarie Jaskolski   50                    Operations Manager      83150
# 77    Camille Buckridge   37                        NASA Scientist     108405
# 80  Thurman Satterfield   30                      Machine Operator      49762
# 81     Delbert Emmerich   54                    Aerospace Engineer     116085
# 84           Jay Walker   50                       Delivery Driver      42545
# 90        Myrtle Hansen   36                       Project Manager      91065
# 96       Alana O'Reilly   24                               Manager      67847
# 97         Humberto Orn   50                     Garbage Collector      26017
# 99         Nettie Stamm   55                             Bartender      32968
#
#     creditScore                  ccNumber  married  hasChildren  height  \
# 3           581             4704370471115     True         True   155.0
# 9           736       3529-5258-4279-6916     True         True   161.0
# 15          708             4213267875131     True         True   161.0
# 17          538    6759-0615-0632-5009-94     True         True   156.0
# 18          514       4707-1570-6462-4709     True         True   161.0
# 19          386       6771-8954-9376-0414     True         True   151.0
# 23          466       6011-7827-7010-0896    False         True   170.0
# 26          642          3681-930146-1803    False         True   160.0
# 30          765       5019-1335-0342-2245     True         True   161.0
# 31          813          6771761273014093     True         True   151.0
# 42          444       6771-8941-5623-1235     True         True   170.0
# 46          589   6759-8023-4877-4550-956     True         True   160.0
# 47          779         3792-455946-41643    False         True   160.0
# 51          727  6503-6250-2122-3546-3795    False         True   161.0
# 54          556          6706717800371877     True         True   160.0
# 57          353          6304116710570395     True         True   170.0
# 58          556       6007-2216-9644-9893     True         True   156.0
# 59          448          6709792648095878     True         True   180.0
# 60          410          3685-844672-7371    False         True   165.0
# 63          400       4388-2597-9697-5932     True         True   160.0
# 68          444       6771-8985-4448-9470     True         True   165.0
# 72          826   6759-3251-4715-9743-949     True         True   176.0
# 73          526          3681-485687-6018     True         True   155.0
# 77          556       6007-2292-9057-6821     True         True   166.0
# 80          594       6007-2202-0295-3208     True         True   165.0
# 81          522       6771-8980-9089-7639    False         True   165.0
# 84          829       3529-7027-5587-1719     True         True   166.0
# 90          627  6011-6278-6874-0077-5607     True         True   171.0
# 96          645          3683-983855-9689     True         True   161.0
# 97          543       6771-8935-4748-6904     True         True   161.0
# 99          559  6527-6293-9260-8551-8769    False         True   166.0
#
#     weight  ...                            email  gender hasDegree  bloodType  \
# 3     44.1  ...        ziemann.ziemann@yahoo.com  Female     False         B-
# 9     59.9  ...              romaguera@gmail.com    Male     False         B+
# 15    61.0  ...           retha.rempel@gmail.com  Female     False         B-
# 17    70.5  ...        ulyssesschulist@gmail.com    Male     False         A+
# 18    65.1  ...            berge.allie@yahoo.com    Male     False         A-
# 19    60.3  ...      mitchell.mitchell@yahoo.com    Male     False         B+
# 23    65.1  ...      roderick.roderick@yahoo.com  Female     False        AB-
# 26    65.1  ...                milissa@gmail.com    Male      True         A+
# 30    64.5  ...           bree_huels@hotmail.com  Female     False        AB+
# 31    50.3  ...                  jones@yahoo.com  Female      True         A-
# 42    65.9  ...                valward@yahoo.com  Female      True         B-
# 46    70.3  ...                  kulas@gmail.com    Male     False         B+
# 47    69.9  ...        jeffrey_quitzon@gmail.com    Male     False         A+
# 51    45.2  ...            cyrus_terry@gmail.com  Female     False         B+
# 54    60.1  ...        simon_reinger@hotmail.com  Female     False         B-
# 57    65.1  ...          denisweissnat@yahoo.com  Female      True         A-
# 58    65.6  ...          marla.marla@hotmail.com    Male     False         A+
# 59    69.8  ...          norman_larkin@gmail.com    Male     False         A+
# 60    64.2  ...          harvey.jennie@gmail.com    Male     False         B+
# 63    70.8  ...                 jewell@gmail.com  Female      True         A-
# 68    70.0  ...         shamika.hessel@gmail.com    Male      True         A+
# 72    50.4  ...       valarie.schimmel@gmail.com    Male     False         A-
# 73    50.5  ...  annemarie_jaskolski@hotmail.com  Female     False         A+
# 77    75.0  ...      camille_buckridge@gmail.com    Male     False         A-
# 80    65.5  ...    thurman_satterfield@gmail.com   Other     False         A+
# 81    71.0  ...                delbert@gmail.com    Male     False         A-
# 84    60.8  ...                    jay@yahoo.com  Female     False         A+
# 90    70.8  ...          myrtle_hansen@gmail.com  Female      True        AB+
# 96    64.6  ...            alana.alana@gmail.com    Male     False         B+
# 97    64.3  ...           humberto_orn@yahoo.com    Male     False         B+
# 99    55.6  ...           stamm.nettie@gmail.com  Female     False         B-
#
#        username politicalLeaning        religion  \
# 3        mack78            -0.77    Christianity
# 9       shelby5             0.01        Buddhism
# 15      retha31            -0.41        Hinduism
# 17    ulysses16             0.56  Folk Religions
# 18      allie49            -0.46           Islam
# 19  ellsworth91            -0.35           Islam
# 23   roderick88            -0.35        Hinduism
# 26     milissa1            -0.44        Buddhism
# 30       bree76             0.04        Hinduism
# 31   reynaldo47             0.24    Christianity
# 42        val56             0.07       Christian
# 46      zoila24            -0.32    Christianity
# 47    jeffrey92            -0.11        Hinduism
# 51      cyrus90            -0.66           Islam
# 54      simon24             0.12           Islam
# 57       denis6            -0.42        Buddhism
# 58      marla24            -0.75           Islam
# 59     norman98             0.18           Islam
# 60     jennie38             1.00           Islam
# 63      jewell2            -0.25    Christianity
# 68    shamika73            -0.44        Hinduism
# 72     valarie3            -0.94          Muslim
# 73  annemarie69            -0.21        Hinduism
# 77    camille55             0.76        Hinduism
# 80    thurman42            -0.60    Christianity
# 81    delbert46            -0.11        Hinduism
# 84        jay58             0.49    Christianity
# 90     myrtle36            -0.16           Islam
# 96      alana24             0.61    Christianity
# 97   humberto21             0.36           Islam
# 99     nettie24            -0.13    Christianity
#
#                                               address  \
# 3   {'streetAddress': '12598 Rayford Cape', 'city'...
# 9   {'streetAddress': '96662 Blanda Landing', 'cit...
# 15  {'streetAddress': '9589 Odette Station', 'city...
# 17  {'streetAddress': '847 Maricruz Heights', 'cit...
# 18  {'streetAddress': '50648 Latoya Inlet', 'city'...
# 19  {'streetAddress': '73322 Dorethea Haven', 'cit...
# 23  {'streetAddress': '66197 Robel Dam', 'city': '...
# 26  {'streetAddress': '711 Joey Square', 'city': '...
# 30  {'streetAddress': '48513 Walsh Lake', 'city': ...
# 31  {'streetAddress': '49790 Koss Run', 'city': 'T...
# 42  {'streetAddress': '47692 Frances View', 'city'...
# 46  {'streetAddress': '729 Gaylord Fork', 'city': ...
# 47  {'streetAddress': '24 Kuhlman Terrace', 'city'...
# 51  {'streetAddress': '7524 Kub Ridge', 'city': 'K...
# 54  {'streetAddress': '863 Batz Underpass', 'city'...
# 57  {'streetAddress': '001 Classie Mill', 'city': ...
# 58  {'streetAddress': '50115 Abbott Park', 'city':...
# 59  {'streetAddress': '55252 Gutkowski Rest', 'cit...
# 60  {'streetAddress': '5229 Nicky Pike', 'city': '...
# 63  {'streetAddress': '8464 Rolfson Mission', 'cit...
# 68  {'streetAddress': '2802 Farrell Rue', 'city': ...
# 72  {'streetAddress': '61139 Lockman Coves', 'city...
# 73  {'streetAddress': '9000 Billy Tunnel', 'city':...
# 77  {'streetAddress': '324 Vernice Crossing', 'cit...
# 80  {'streetAddress': '944 Shantae Isle', 'city': ...
# 81  {'streetAddress': '7520 Yesenia Square', 'city...
# 84  {'streetAddress': '766 Harold Square', 'city':...
# 90  {'streetAddress': '210 Ailene Burg', 'city': '...
# 96  {'streetAddress': '38931 Shakita Falls', 'city...
# 97  {'streetAddress': '4758 Smitham Plain', 'city'...
# 99  {'streetAddress': '435 Jenkins Road', 'city': ...
#
#                              doB  gpa
# 3   Wed Aug 20 23:46:15 UTC 1997  2.3
# 9   Mon Apr 17 01:14:46 UTC 2000  0.0
# 15  Fri Apr 02 22:08:05 UTC 1954  3.4
# 17  Thu Jan 15 15:58:20 UTC 1970  3.3
# 18  Fri Oct 22 07:03:10 UTC 1982  2.0
# 19  Sat Nov 08 05:55:29 UTC 2003  3.9
# 23  Sun Nov 20 00:06:34 UTC 1955  3.8
# 26  Tue Mar 27 07:28:26 UTC 1984  4.0
# 30  Sat Sep 13 06:37:07 UTC 1997  4.0
# 31  Fri May 30 04:26:35 UTC 1980  3.2
# 42  Sun Jul 15 21:50:41 UTC 1973  4.0
# 46  Sun Nov 24 00:28:32 UTC 1991  3.1
# 47  Thu Feb 13 06:31:24 UTC 1975  3.1
# 51  Wed Jan 28 18:01:05 UTC 1970  3.3
# 54  Sun Sep 17 23:06:30 UTC 2000  3.2
# 57  Wed Jan 08 21:51:10 UTC 2003  4.0
# 58  Tue Aug 22 10:46:26 UTC 1967  3.6
# 59  Wed Apr 05 21:35:21 UTC 1989  3.6
# 60  Tue Nov 12 07:25:50 UTC 2002  3.4
# 63  Mon Feb 19 21:15:37 UTC 1990  3.6
# 68  Sun Jun 25 04:57:44 UTC 1995  0.8
# 72  Fri Jun 17 04:46:32 UTC 1977  1.6
# 73  Sat Nov 17 05:08:38 UTC 1973  0.8
# 77  Sun Mar 01 23:15:18 UTC 1987  1.5
# 80  Wed Dec 14 00:06:44 UTC 1994  2.8
# 81  Mon Nov 10 16:38:44 UTC 1969  2.2
# 84  Sun Aug 26 13:03:44 UTC 1973  2.2
# 90  Fri Jan 22 17:23:49 UTC 1988  3.0
# 96  Tue Feb 01 12:47:36 UTC 2000  2.4
# 97  Wed Oct 24 11:39:39 UTC 1973  2.9
# 99  Sat Jun 28 14:32:13 UTC 1969  3.0
#
# [31 rows x 21 columns]

# %%
#Select and print the SECOND AND THIRD columns of your data frame.

columns_print = [1,2]
selected_columns = maskdf.iloc[:, columns_print]
print(selected_columns)
# Out:
#     age                                   job
# 3    26                      Nuclear Engineer
# 9    24                    Physical Therapist
# 15   70                               Retired
# 17   54                            Lumberjack
# 18   41                     Marketing Manager
# 19   21                        E-Sports Coach
# 23   68                        NASA Scientist
# 26   40                      Graphic Designer
# 30   27                    Facilities Manager
# 31   44                       Insurance Agent
# 42   51                  Assembly Line Worker
# 46   32       Workforce Management Specialist
# 47   49                             Paralegal
# 51   54                               Auditor
# 54   23  Chief Human Resources Officer (CHRO)
# 57   21                           Demographer
# 58   56                           Audiologist
# 59   35                        Office Manager
# 60   21               Costume Designer (Film)
# 63   34                      Marine Biologist
# 68   29               Human Resources Manager
# 72   47               Market Research Analyst
# 73   50                    Operations Manager
# 77   37                        NASA Scientist
# 80   30                      Machine Operator
# 81   54                    Aerospace Engineer
# 84   50                       Delivery Driver
# 90   36                       Project Manager
# 96   24                               Manager
# 97   50                     Garbage Collector
# 99   55                             Bartender

# %%
#Select and print the FIRST 4 rows of you data frame.

maskdf.iloc[:4]
# Out:
#                 name  age                 job  incomeUSD  creditScore  \
# 3       Mack Ziemann   26    Nuclear Engineer      80162          581
# 9   Shelby Romaguera   24  Physical Therapist      93238          736
# 15      Retha Rempel   70             Retired          0          708
# 17  Ulysses Schulist   54          Lumberjack      50065          538
#
#                   ccNumber  married  hasChildren  height  weight  ...  \
# 3            4704370471115     True         True   155.0    44.1  ...
# 9      3529-5258-4279-6916     True         True   161.0    59.9  ...
# 15           4213267875131     True         True   161.0    61.0  ...
# 17  6759-0615-0632-5009-94     True         True   156.0    70.5  ...
#
#                         email  gender hasDegree  bloodType   username  \
# 3   ziemann.ziemann@yahoo.com  Female     False         B-     mack78
# 9         romaguera@gmail.com    Male     False         B+    shelby5
# 15     retha.rempel@gmail.com  Female     False         B-    retha31
# 17  ulyssesschulist@gmail.com    Male     False         A+  ulysses16
#
#    politicalLeaning        religion  \
# 3             -0.77    Christianity
# 9              0.01        Buddhism
# 15            -0.41        Hinduism
# 17             0.56  Folk Religions
#
#                                               address  \
# 3   {'streetAddress': '12598 Rayford Cape', 'city'...
# 9   {'streetAddress': '96662 Blanda Landing', 'cit...
# 15  {'streetAddress': '9589 Odette Station', 'city...
# 17  {'streetAddress': '847 Maricruz Heights', 'cit...
#
#                              doB  gpa
# 3   Wed Aug 20 23:46:15 UTC 1997  2.3
# 9   Mon Apr 17 01:14:46 UTC 2000  0.0
# 15  Fri Apr 02 22:08:05 UTC 1954  3.4
# 17  Thu Jan 15 15:58:20 UTC 1970  3.3
#
# [4 rows x 21 columns]
